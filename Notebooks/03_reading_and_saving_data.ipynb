# %% [markdown]
# In order to save and read data in Google Colab, we need to first import Google infrastructure.

# %%
from google.colab import drive

# %% [markdown]
# After import we can now mount our google drive

# %%
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive
